# %%
import numpy as np

# 넘파이는 여러가지 산술연산을 도와준다.

# %%
x = np.array([1.0,2.0,3.0])
print(x)
# Out:
# [1. 2. 3.]

# %%
type(x)
# Out:
# numpy.ndarray

# %%
y = np.array([2.0,4.0,6.0])

# %%
x+y
# Out:
# array([3., 6., 9.])

# %%
x-y
# Out:
# array([-1., -2., -3.])

# %%
x/y
# Out:
# array([0.5, 0.5, 0.5])

# %% [markdown]
# 넘파이 배열은  원소별 계산뿐 아니라 넘파이 배열과 수치 하나(스칼라값) 의 조합으로 된 산술 연산도 수행이 가능하다.

# %%
#넘파이의 다차원 배열

A = np.array([[1,2],[3,4]])
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A= np.array([[1,2],[3,4]])
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A.shape
# Out:
# (2, 2)

# %%
B = np.array([[3,0],[0,6]])
print(B)
# Out:
# [[3 0]
#  [0 6]]

# %%
A+B
# Out:
# array([[ 4,  2],
#        [ 3, 10]])

# %% [markdown]
# 수학에서는 1차원 배열은 벡터 2차원 배열은 행렬 3차원 이상은 다차원 배열이라고 합니다. 또 벡터와  행렬을 일반화 한것을 텐서라고 합니다.

# %% [markdown]
# ### 브로드 캐스트
#
# 넘파이에서는 형상이 다른 배열끼리도 계산할 수 있습니다.

# %%
A= np.array([[1,2],[3,4]])
B= np.array([10,20])

# %%
A*10
# Out:
# array([[10, 20],
#        [30, 40]])

# %%
A*B
# Out:
# array([[10, 40],
#        [30, 80]])

# %% [markdown]
# ### 원소 접근

# %%
X= np.array([[51,55],[14,19],[0,4]])
print(X)
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]

# %%
X[2][1]
# Out:
# 4

# %% [markdown]
# 55 찾기

# %%
X[0][1]
# Out:
# 55

# %% [markdown]
# For 문으로도 각 원소에 접근 할 수 있습니다.

# %%
X
# Out:
# array([[51, 55],
#        [14, 19],
#        [ 0,  4]])

# %%
for i in X:
    for j in i:
        print(j,end = (' '))
# Out:
# 51 55 14 19 0 4

# %%
for i in X: # 각 행별로 가져오는 것을 확인 할 수 있다.
    print(i)
# Out:
# [51 55]
# [14 19]
# [0 4]

# %%
for i in X:  # 각 원소 가져오기 
    for j in i:
        print(j,end = (' '))
# Out:
# 51 55 14 19 0 4

# %%
X= X.flatten()  # X를  1차원 배열로(평탄화)

print(X)
# Out:
# [51 55 14 19  0  4]

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X=X.tolist()

# %%
type(X)
# Out:
# list

# %%
X[0]
# Out:
# 51

# %%
X[np.array([0,2,4])] # index가 0, 2, 4 인 것을 얻기
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9776\826767760.py in <module>
# ----> 1 X[np.array([0,2,4])] # index가 0, 2, 4 인 것을 얻기
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %% [markdown]
# flatten기법을 이용하면 특정 값을 만족하는 값을 구할 수 있습니다.

# %%
X>15

# %%
X[X>15] # 값이 15보다 큰 값만 꺼내기

# %% [markdown]
# 파이썬 같은 동적 언어는 C 나 C++ 같은 정적 언어(컴파일언어) 보다 처리 속도가 늦다고 합니다. 실제로 무거운 작업을 할 때는 c/c++ 로 작성한 프로그램을 쓰는 편이 좋습니다. 그래서 파이썬에서 빠른 성능이 요구 될 경우 해당 부분을 C/C++ 로 구현하곤 합니다. 파이썬은  중개자 역할을 합니다. 그래서 성능을 해치지 않으면서 편리한 문법을 사용할 수 있죠.

# %% [markdown]
# # matplotlib

# %% [markdown]
# matplotlib은 데이터 시각화를 도와주는 라이브러리입니다.

# %% [markdown]
# ### 단순한 그래프 그리기

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt # matplotlib의 pyplot 모듈을 이용합니다.

# 데이터 준비

x = np.arange(0,6,0.1) # 0에서 6 까지 0.1 간격으로 생성
y = np.sin(x)

plt.plot(x,y)
plt.show

# %%
x= np.arange(0,6,0.1)
y= np.sin(x)

plt.plot(x,y)
plt.show

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import time

start = time.time()
for x in range(10*5): print(x*2) #  0부터 49까지 빼와서 2를 곱한값을 출력해라

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# ## linespace  문법 정리
#
# https://jimmy-ai.tistory.com/41

# %% [markdown]
# 파이썬에서 넘파이 라이브러리를 사용하다보면 예를 들어, y = sin x 같은 그래프를 그리고 싶을 때에
#
# x를 어떻게 지정해야하는지 궁금해지는 경우가 있습니다.
#
#
#
# 이런 경우 구간 내에 숫자를 균일한 간격으로 촘촘하게 채울 수 있는 np.linspace 함수에 대해서 간단한 설명을 해보도록 하겠습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.linspace(1,2,10) #1과 2 사이를 10등분으로 쪼갠다 느낌

# %% [markdown]
# 여기서 끝점을 포함하지 않고 싶으면 endpoint = False를 추가해주시면 되고,
#
# retstep = True를 추가하시면 숫자 사이의 간격이 얼마인지에 대한 값을 같이 반환하게 됩니다. 예제를 간단히 보여드리겠습니다.

# %%
np.linspace(1,2,10,endpoint = False)

# %%
np.linspace(1,2,10,retstep = True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 간격 10개

x = np.linspace(0,2 *np.pi,10)
y = np.sin(x)
plt.plot(x,y, color ='r')
plt.show()

# %%
# 간격 100개

x = np.linspace(0,2 *np.pi,100)
y = np.sin(x)
plt.plot(x,y, color ='r')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10]) #(1,2), #(2,3),(3,5),(4,10)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0, 5, 0, 20])  # X, Y축의 범위: [xmin, xmax, ymin, ymax]

plt.show()

# %% [markdown]
# https://wikidocs.net/92071 # python ㅡmatplot 링크

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
import os



print(os.getcwd()) #현재 작업 디렉토리 표시
# Out:
# C:\Users\Administrator\jupyter

# %%
#PATH= os.getcwd() + '\img' #현재 경로에  img 폴더를 더한 최종경로 
PATH ='C:\\Users\\Administrator\\jupyter\\img'
os.chdir(PATH) #현재 작업경로를 토끼가 있는 img 폴더로 바꿔준다.
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\jupyter\\img'

# %%
img= imread('토끼.png')

plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
