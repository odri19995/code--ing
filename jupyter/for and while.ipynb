# %%
for letter in 'Python':
    print(letter, end=' ')
# Out:
# P y t h o n

# %%
for letter in reversed('Python'):
    print(letter, end= ' ')
# Out:
# n o h t y P

# %% [markdown]
# ## 16.5 연습문제: 리스트의 요소에 10을 곱해서 출력하기
# 다음 소스 코드를 완성하여 리스트 x에 들어있는 각 숫자(요소)에 10을 곱한 값이 출력되게 만드세요. 모든 숫자는 공백으로 구분하여 한 줄로 출력되어야 합니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x =[49, -17, 25, 102, 8 , 62, 21]

for i in x:
    print(i*10, end= ' ')
# Out:
# 490 -170 250 1020 80 620 210

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("1-1칸","1-2칸","1-3칸")
print("2-1칸","2-2칸","2-3칸")
# Out:
# 1-1칸 1-2칸 1-3칸
# 2-1칸 2-2칸 2-3칸

# %% [markdown]
# 앞서 말한 것과 같이 print안에 여러 개의 값을 출력할 경우 값들 사이에 공백이 들어가 있으며,
#
# print문이 끝나게 될 경우 개행(\n)이 되는 것을 확인할 수 있습니다.

# %% [markdown]
# 이제 띄어쓰기가 되는 것과 개행을 안되게 하기 위해 sep와 end를 사용해 보겠습니다.

# %%
print("1-1칸","1-2칸","1-3칸",end = "")
print("2-1칸","2-2칸","2-3칸",sep = "")
# Out:
# 1-1칸 1-2칸 1-3칸2-1칸2-2칸2-3칸

# %%
print("1-1칸","1-2칸","1-3칸",end = "")
# Out:
# 1-1칸 1-2칸 1-3칸

# %%
print("1-1","1-2","1-3",end = "")
# Out:
# 1-1 1-2 1-3

# %%
x =[49, -17, 25, 102, 8 , 62, 21]

for i in x:
    print(i*10, end= ' ') #반복문에서는 공백 처리를 따로 해줘야 하는 것 같다.  end는 한줄로 입력이 가능하게 한다.
# Out:
# 490 -170 250 1020 80 620 210

# %% [markdown]
# 표준 입력으로 정수가 입력됩니다. 입력된 정수의 구구단을 출력하는 프로그램을 만드세요(input에서 안내 문자열은 출력하지 않아야 합니다). 출력 형식은 숫자 * 숫자 = 숫자처럼 만들고 숫자와 *, = 사이는 공백을 한 칸 띄웁니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = int(input())

for i in range(1,10):
    print("{0} * {1} =".format(x,i),x*i)
# Out:
# 2
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18

# %%
x = int(input())

for i in range(1,10):
    print(x, "*", i, "=", x*i)
# Out:
# 2
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
